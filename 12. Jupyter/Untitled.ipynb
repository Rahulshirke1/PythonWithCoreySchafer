# %%
name = "Rahul"

# %%
name
# Out:
# 'Rahul'

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# annotated-types              0.7.0
# anyio                        4.9.0
# argon2-cffi                  25.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# async-lru                    2.0.5
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.4
# bleach                       6.2.0
# blinker                      1.9.0
# bs4                          0.0.2
# cachetools                   5.5.2
# certifi                      2025.7.14
# cffi                         1.17.1
# charset-normalizer           3.4.2
# click                        8.2.1
# colorama                     0.4.6
# comm                         0.2.2
# debugpy                      1.8.15
# decorator                    5.2.1
# defusedxml                   0.7.1
# distlib                      0.4.0
# ...

# %%
# %pwd
# Out:
# 'C:\\2022-2023\\All the python program\\Corey Schafer\\learning\\Jupyter'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7C0D-20DE
#
#  Directory of C:\2022-2023\All the python program\Corey Schafer\learning\Jupyter
#
# 22-07-2025  23:39    <DIR>          .
# 22-07-2025  19:07    <DIR>          ..
# 22-07-2025  23:19    <DIR>          .ipynb_checkpoints
# 22-07-2025  23:14               740 jupyter.txt
# 22-07-2025  23:39             8,132 Untitled.ipynb
#                2 File(s)          8,872 bytes
#                3 Dir(s)  154,744,815,616 bytes free

# %%
# %ls -la
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7C0D-20DE
#
#  Directory of C:\2022-2023\All the python program\Corey Schafer\learning\Jupyter
# File Not Found

# %%
# %%HTML
# <h1>Hello World</h1>
# Out:
#   Cell In[28], line 2
#     <h1>Hello World</h1>
#     ^
# SyntaxError: invalid syntax

# %%
# %%HTML
# <h1>Hello world</h1>
# Out:
# <h1>Hello world</h1>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,5))
df
# Out:
#           0         1         2         3         4
# 0 -0.373798 -0.088331  0.305716  1.081347  0.187322
# 1 -0.777001 -0.235676  0.206070  0.095905 -0.333865
# 2 -0.107355  0.830677 -0.250852 -1.194753 -0.387018
# 3  0.355346  0.231323  1.691605  1.010769  0.027316
# 4  2.982007 -0.018386  0.513937 -0.141261 -1.958847
# 5 -0.578502 -0.150817 -0.632265 -0.624090  0.942618
# 6  0.091185 -0.170863 -0.536375 -0.354859  0.309988
# 7  0.721821 -0.106888  1.146403  0.698495  2.155089
# 8 -0.488952 -0.709381  0.298110 -0.091950 -0.050764
# 9  0.333799 -0.029644  0.889885  0.059665 -1.027341

# %%
pip install pandas numpy
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.3 MB 4.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.3 MB 4.3 MB/s eta 0:00:02
#    ------------ --------------------------- 3.7/11.3 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.3 MB 4.1 MB/s eta 0:00:02
#    ------------------ --------------------- 5.2/11.3 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.3 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.3 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 4.0 MB/s eta 0:00:01
# ...
